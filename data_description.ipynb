# %%
import pandas as pd
btc_data = pd.read_csv('market_data_sample.csv',  low_memory=False)
btc_data.head()
# Out:
#        Open time      Open      High       Low     Close       Volume  \
# 0  1673845200000  21147.98  21216.70  21119.05  21187.16   6954.41915
# 1  1673848800000  21187.89  21260.00  21106.96  21149.80  10204.48252
# 2  1673852400000  21149.80  21159.70  21066.23  21109.23   7602.55388
# 3  1673856000000  21109.40  21113.22  20666.00  20747.70  24188.23332
# 4  1673859600000  20746.75  20840.00  20720.00  20824.08   9658.96868
#
#       Close time  Quote asset volume  Number of trades  \
# 0  1673848799999        1.471986e+08            212925
# 1  1673852399999        2.159828e+08            275289
# 2  1673855999999        1.604160e+08            228737
# 3  1673859599999        5.032742e+08            473418
# 4  1673863199999        2.008177e+08            245721
#
#    Taker buy base asset volume  Taker buy quote asset volume  Ignore
# 0                   3511.07101                  7.431867e+07       0
# 1                   4987.49439                  1.055738e+08       0
# ...

# %%
btc_data["Open"].plot()
# Out:
# <AxesSubplot:>

# %%
btc_data.describe()
# Out:
#           Open time          Open          High           Low         Close  \
# count  5.000000e+02    500.000000    500.000000    500.000000    500.000000
# mean   1.674743e+12  22654.561040  22734.464340  22573.115580  22658.375140
# std    5.201346e+08    913.694602    912.504705    912.887262    911.401881
# min    1.673845e+12  20677.470000  20764.640000  20407.150000  20677.470000
# 25%    1.674294e+12  22583.732500  22648.412500  22499.500000  22592.652500
# 50%    1.674743e+12  22967.185000  23035.805000  22878.770000  22967.565000
# 75%    1.675192e+12  23203.742500  23300.117500  23117.810000  23204.665000
# max    1.675642e+12  24188.090000  24255.000000  23946.590000  24189.850000
#
#              Volume    Close time  Quote asset volume  Number of trades  \
# count    500.000000  5.000000e+02        5.000000e+02      5.000000e+02
# mean   11879.139509  1.674747e+12        2.691128e+08      2.911927e+05
# ...
